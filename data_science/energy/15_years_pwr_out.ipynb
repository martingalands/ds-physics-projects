# %% [markdown]
# Content
# The dataset contains outage data from year 2000 up until 2014, with the following information:
#
# Event Description: Reason of the outage (e.g. Vandalistm, Severe Weather, etc)\
# Year: Year of the outage (e.g. 2014)\
# Month: Month of the outage (e.g. November)\
# Date Event Began: Date of the outage (e.g. 11/13/2017)\
# Time Event Began: Time the outage was registered (e.g. 15:05:00)\
# Date of Restoration: Date the outage was resolved\
# Time of Restoration: Time the outage was resolved\
# Respondent: The company that acted upon the outage
# Geografic Area: Region of the outage (e.g. Missisippi, Texas, New York, Salt Lake City, etc)\
# NERG Region: (NERC refers to the North American Electricity Reliability Corporation, formed to ensure the reliability of the grid).\
# Demand Loss (MW): How much energy was not transmited/consumed during the outage.\
# Number of customers affected: How many consumers (e.g. homes, offices, industry, etc) were left to their devices.\
# Tags: Summary event description (e.g. wild fire, vandalism, severe weather)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\DELL\Desktop\Data\datasets\raws\15_years_pwr_out\Grid_Disruption_00_14_standardized - Grid_Disruption_00_14_standardized.csv')

# %%
df[['cause_1','cause_2','cause_3','cause_4']] = df['Tags'].str.split(',', expand=True)
df.drop(columns='Tags')
# Out:
#                    Event Description  Year Date Event Began Time Event Began  \
# 0     Severe Weather - Thunderstorms  2014        6/30/2014          8:00 PM
# 1     Severe Weather - Thunderstorms  2014        6/30/2014         11:20 PM
# 2     Severe Weather - Thunderstorms  2014        6/30/2014          5:55 PM
# 3       Fuel Supply Emergency - Coal  2014        6/27/2014          1:21 PM
# 4        Physical Attack - Vandalism  2014        6/24/2014          2:54 PM
# ...                              ...   ...              ...              ...
# 1647          Transmission Line Loss  2000        3/18/2000        4:00 p.m.
# 1648                       Vandalism  2000        3/14/2000        9:06 p.m.
# 1649                       Ice Storm  2000        1/29/2000       10:00 p.m.
# 1650                       Ice Storm  2000        1/24/2000        7:00 p.m.
# 1651                       Ice Storm  2000        1/23/2000        8:00 a.m.
#
#      Date of Restoration Time of Restoration  \
# 0               7/2/2014             6:30 PM
# 1               7/1/2014             5:00 PM
# 2               7/1/2014             2:53 AM
# 3                Unknown             Unknown
# 4              6/24/2014             2:55 PM
# ...                  ...                 ...
# 1647           3/18/2000          5:10:00 PM
# 1648                 NaN                 NaN
# 1649            2/3/2000         12:00:00 PM
# 1650                 NaN                 NaN
# 1651           1/28/2000         12:00:00 PM
#
#                                    Respondent  \
# 0                    Exelon Corporation/ComEd
# 1     Northern Indiana Public Service Company
# 2                                 We Energies
# 3                                 We Energies
# 4                  Tennessee Valley Authority
# ...                                       ...
# 1647                        El Paso Elec. Co.
# 1648                           Alliant Energy
# 1649                           Duke Power Co.
# 1650                   Carolina Power & Light
# 1651                           Duke Power Co.
#
#                               Geographic Areas NERC Region Demand Loss (MW)  \
# 0                                     Illinois         RFC          Unknown
# 1                        North Central Indiana         RFC          Unknown
# 2                         Southeast  Wisconsin         MRO              424
# 3                                    Wisconsin         MRO          Unknown
# 4                         Nashville, Tennessee        SERC          Unknown
# ...                                        ...         ...              ...
# 1647                                     Texas        MAIN              400
# 1648                                     Maine        MAIN              NaN
# 1649                            South Carolina        SERC              300
# 1650  North Carolina & Northern South Carolina        SERC              960
# 1651                            South Carolina        SERC              450
#
#      Number of Customers Affected                    cause_1        cause_2  \
# 0                         420,000             severe weather   thunderstorm
# 1                         127,000             severe weather   thunderstorm
# 2                         120,000             severe weather   thunderstorm
# 3                         Unknown      fuel supply emergency           coal
# 4                         Unknown                  vandalism       physical
# ...                           ...                        ...            ...
# 1647                      100,000  transmission interruption            NaN
# 1648                          NaN                  vandalism            NaN
# 1649                       81,000             severe weather   winter storm
# 1650                      173,000             severe weather   winter storm
# 1651                      133,000             severe weather   winter storm
#
#      cause_3 cause_4
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN
# ...      ...     ...
# 1647     NaN     NaN
# 1648     NaN     NaN
# 1649     NaN     NaN
# 1650     NaN     NaN
# 1651     NaN     NaN
#
# [1652 rows x 15 columns]

# %%
df.cause_2.value_counts()
# Out:
# cause_2
# thunderstorm                 225
# physical                     200
# winter storm                 155
# hurricane/tropical storm     114
# wind                          92
# storm                         56
# cold                          25
# public appeal                 22
# coal                          20
# load shedding                 17
# cyber                         14
# tornado                       12
# transmission interruption     11
# heat                          11
# natural gas                    9
# equipment failure              7
# voltage reduction              7
# hydro                          6
# severe weather                 5
# generator trip                 4
# wild fire                      4
# hail                           3
# flooding                       3
# fog                            1
# petroleum                      1
# dust                           1
# distribution interruption      1
# islanding                      1
# Name: count, dtype: int64

# %%
electrical_causes = ['uncontrolled loss',
                     'energy deficiency alert',
                     'distribution interruption',
                     'generator trip',
                     'transmission interruption',
                     'fuel supply emergency',
                     'voltage reduction',
                     'equipment failure']

# %%
every_cause = pd.Series(df.cause_1.unique())

for c in ['cause_2','cause_3','cause_4']:
    pd.concat([every_cause,pd.Series(df[c].unique())])

every_cause
# Out:
# 0                severe weather
# 1         fuel supply emergency
# 2                     vandalism
# 3                     islanding
# 4                     wild fire
# 5                 load shedding
# 6             voltage reduction
# 7                 public appeal
# 8             equipment failure
# 9     transmission interruption
# 10    distribution interruption
# 11      energy deficiency alert
# 12                   earthquake
# 13        low flying helicopter
# 14                 breaker trip
# 15               generator trip
# 16                      unknown
# 17            uncontrolled loss
# 18                          NaN
# dtype: str
